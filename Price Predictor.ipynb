# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load the data set

# %%
dataset=pd.read_csv('Boston.csv')

# %%
dataset.head()
# Out:
#       crim    zn  indus    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   nox      506 non-null    float64
#  4   rm       506 non-null    float64
#  5   age      506 non-null    float64
#  6   dis      506 non-null    float64
#  7   rad      506 non-null    int64
#  8   tax      506 non-null    int64
#  9   ptratio  506 non-null    float64
#  10  black    506 non-null    float64
#  11  lstat    506 non-null    float64
#  12  price    506 non-null    float64
# dtypes: float64(11), int64(2)
# memory usage: 51.5 KB

# %%
## Summarizing the stat of data
dataset.describe()
# Out:
#              crim          zn       indus         nox          rm         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.554695    6.284634   68.574901
# std      8.601545   23.322453    6.860353    0.115878    0.702617   28.148861
# min      0.006320    0.000000    0.460000    0.385000    3.561000    2.900000
# 25%      0.082045    0.000000    5.190000    0.449000    5.885500   45.025000
# 50%      0.256510    0.000000    9.690000    0.538000    6.208500   77.500000
# 75%      3.677083   12.500000   18.100000    0.624000    6.623500   94.075000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               dis         rad         tax     ptratio       black       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043    9.549407  408.237154   18.455534  356.674032   12.653063
# std      2.105710    8.707259  168.537116    2.164946   91.294864    7.141062
# min      1.129600    1.000000  187.000000   12.600000    0.320000    1.730000
# 25%      2.100175    4.000000  279.000000   17.400000  375.377500    6.950000
# 50%      3.207450    5.000000  330.000000   19.050000  391.440000   11.360000
# 75%      5.188425   24.000000  666.000000   20.200000  396.225000   16.955000
# max     12.126500   24.000000  711.000000   22.000000  396.900000   37.970000
#
#             price
# count  506.000000
# mean    22.532806
# std      9.197104
# min      5.000000
# 25%     17.025000
# 50%     21.200000
# 75%     25.000000
# max     50.000000

# %% [markdown]
# ## Check the missing value

# %%
dataset.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# price      0
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis

# %%
## Correlation

# %%
dataset.corr()
# Out:
#              crim        zn     indus       nox        rm       age       dis  \
# crim     1.000000 -0.200469  0.406583  0.420972 -0.219247  0.352734 -0.379670
# zn      -0.200469  1.000000 -0.533828 -0.516604  0.311991 -0.569537  0.664408
# indus    0.406583 -0.533828  1.000000  0.763651 -0.391676  0.644779 -0.708027
# nox      0.420972 -0.516604  0.763651  1.000000 -0.302188  0.731470 -0.769230
# rm      -0.219247  0.311991 -0.391676 -0.302188  1.000000 -0.240265  0.205246
# age      0.352734 -0.569537  0.644779  0.731470 -0.240265  1.000000 -0.747881
# dis     -0.379670  0.664408 -0.708027 -0.769230  0.205246 -0.747881  1.000000
# rad      0.625505 -0.311948  0.595129  0.611441 -0.209847  0.456022 -0.494588
# tax      0.582764 -0.314563  0.720760  0.668023 -0.292048  0.506456 -0.534432
# ptratio  0.289946 -0.391679  0.383248  0.188933 -0.355501  0.261515 -0.232471
# black   -0.385064  0.175520 -0.356977 -0.380051  0.128069 -0.273534  0.291512
# lstat    0.455621 -0.412995  0.603800  0.590879 -0.613808  0.602339 -0.496996
# price   -0.388305  0.360445 -0.483725 -0.427321  0.695360 -0.376955  0.249929
#
#               rad       tax   ptratio     black     lstat     price
# crim     0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# zn      -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# indus    0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# nox      0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# rm      -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# age      0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# dis     -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# rad      1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# tax      0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# ptratio  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# black   -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# lstat    0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# price   -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
plt.scatter(dataset['crim'],dataset['price'])
plt.xlabel("Crime Rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(dataset['rm'],dataset['price'])

# %%
sns.regplot(x='rm',y='price',data=dataset)
# Out:
# <Axes: xlabel='rm', ylabel='price'>

# %%
## Independent and dependent Features
X=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
X.head()
# Out:
#       crim    zn  indus    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
## Ttrain Test Split 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
## Standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## Print the coefficents and intercept
print(regression.coef_)
# Out:
# [-1.18314206  0.86822876  0.50416219 -1.73783302  2.97798168 -0.24907649
#  -3.0107131   2.38998877 -1.7056595  -2.11103529  1.10589013 -4.02094632]

# %%
print(regression.intercept_)
# Out:
# 23.01581920903955

# %%
## On which Parameter the model has been trained
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
## Prediction with test data
reg_pred=regression.predict(X_test)

# %%
reg_pred
# Out:
# array([28.92343009, 33.78152058, 15.35230427, 25.47744011, 19.34401825,
#        23.22295519, 17.45322531, 14.18535528, 23.50357304, 20.72405723,
#        22.06349658, 18.62459984, -7.53030521, 21.81077044, 19.29983205,
#        26.74245931, 20.90631926,  5.66246897, 40.94794038, 18.02820528,
#        27.65931435, 30.47997828, 10.76198782, 24.27402554, 18.51530931,
#        16.20969883, 23.15934213, 14.66245938, 19.34846367, 19.40446591,
#        22.26769766, 25.39198749, 25.8695806 , 19.10795588, 16.8955998 ,
#        17.92992668, 31.26926338, 20.3010193 , 20.89486035, 24.90478865,
#        13.8533243 , 32.28754656, 43.22674063, 17.39657001, 27.12961712,
#        17.63854772, 13.72160738, 26.17745538, 20.7246846 , 30.2924449 ,
#        21.4962049 , 34.56539883, 15.5757544 , 26.27673544, 39.95175736,
#        23.43502259, 19.4976162 , 33.45841455, 24.91704242, 12.74764813,
#        22.83518329, 31.11951257, 31.9800055 , 16.15027563, 20.85657744,
#        13.44030915, 20.86755248, 26.25244353, 31.33465012, 12.04921528,
#        20.4064044 , 28.11438773, 11.09979867, 16.61204442, 23.9849878 ,
#         5.18484624, 21.50057328, 41.96426574, 18.59330118,  9.21915825,
#        21.07292421, 13.09726069, 21.52212757,  9.57529735, 23.31343683,
#        29.1714175 , 19.57661999, 25.78683192, 29.79970163, 20.45140236,
#        25.69398193,  5.22051809, 20.56492375, 14.85515005, 14.46587735,
#        21.26325001, 25.40704465, -0.9424773 , 13.79970489, 15.710948  ,
#        22.04578535, 24.71748046, 10.83722134, 19.74903285, 23.57568209,
#        12.00486118, 18.51943513, 25.66589521, 21.04710361, 24.6828429 ,
#         7.48853191, 19.20602329, 22.09022112, 27.44117416, 32.63910494,
#        15.46083631, 34.82282061, 12.81691786, 21.11483156, 28.74833239,
#        15.8012013 , 24.92127634,  2.82410157, 24.06159824, 25.91122041,
#        23.25175282, 25.40799154, 33.79981852, 17.75915372, 39.03943269,
#        14.38103647, 25.00129663, 17.87103954, 20.69957032, 10.02759635,
#        21.30362094, 22.48486065, 32.71954279, 31.63085804, 15.45676961,
#        16.86458859, 29.06837341, 24.98209026, 13.57320789,  5.97825011,
#        27.11861274, 20.75168101, 17.85183156, 13.31694186, 40.63309761,
#        16.92462285, 18.77381286])

# %%
## Plot a sctter plot for the prediction
plt.scatter(y_test,reg_pred)

# %%
## residual
residual= y_test-reg_pred
residual
# Out:
# 173   -5.323430
# 274   -1.381521
# 491   -1.752304
# 72    -2.677440
# 452   -3.244018
#          ...
# 441   -0.751832
# 23     1.183058
# 225    9.366902
# 433   -2.624623
# 447   -6.173813
# Name: price, Length: 152, dtype: float64

# %%
## Plot this residual

sns.displot(residual,kind="kde")
# Out:
# /home/dhanushka/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
## Scatter plot with respect to prediction and residual
## Uniform Distribution
plt.scatter(reg_pred,residual)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 3.204325679650178
# 21.697160127874877
# 4.658021052751359

# %% [markdown]
# ## R squarred and adjusted R squarred

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.7088141357902256

# %%
## Display adjusted R-squared
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6836757878008926

# %% [markdown]
# ##  Pickling The Model file For Deployment

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickle_model = pickle.load(open('regmodel.pkl','rb'))
